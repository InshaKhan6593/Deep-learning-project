# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data

data_path = "../data/interim/final_data.csv"

df = pd.read_csv(data_path, parse_dates=["tpep_pickup_datetime"])

# %%
df
# Out:
#        tpep_pickup_datetime  region  total_pickups  avg_pickups
# 0       2016-01-01 00:00:00       0             58         58.0
# 1       2016-01-01 00:15:00       0            120         97.0
# 2       2016-01-01 00:30:00       0            149        123.0
# 3       2016-01-01 00:45:00       0            160        140.0
# 4       2016-01-01 01:00:00       0            187        161.0
# ...                     ...     ...            ...          ...
# 262075  2016-03-31 22:45:00      29             14         16.0
# 262076  2016-03-31 23:00:00      29             17         16.0
# 262077  2016-03-31 23:15:00      29             18         17.0
# 262078  2016-03-31 23:30:00      29             13         15.0
# 262079  2016-03-31 23:45:00      29             14         15.0
#
# [262080 rows x 4 columns]

# %%
# shape of the data

df.shape
# Out:
# (262080, 4)

# %%
# datatypes

df.dtypes
# Out:
# tpep_pickup_datetime    datetime64[ns]
# region                           int64
# total_pickups                    int64
# avg_pickups                    float64
# dtype: object

# %%
# check for missing values

df.isna().sum()
# Out:
# tpep_pickup_datetime    0
# region                  0
# total_pickups           0
# avg_pickups             0
# dtype: int64

# %%
# extract the day of week information
df["day_of_week"] = df["tpep_pickup_datetime"].dt.day_of_week

# extract the month information
df["month"] = df["tpep_pickup_datetime"].dt.month

# %%
# set the datetime column as index

df.set_index("tpep_pickup_datetime", inplace=True)

# %%
df
# Out:
#                       region  total_pickups  avg_pickups  day_of_week  month
# tpep_pickup_datetime
# 2016-01-01 00:00:00        0             58         58.0            4      1
# 2016-01-01 00:15:00        0            120         97.0            4      1
# 2016-01-01 00:30:00        0            149        123.0            4      1
# 2016-01-01 00:45:00        0            160        140.0            4      1
# 2016-01-01 01:00:00        0            187        161.0            4      1
# ...                      ...            ...          ...          ...    ...
# 2016-03-31 22:45:00       29             14         16.0            3      3
# 2016-03-31 23:00:00       29             17         16.0            3      3
# 2016-03-31 23:15:00       29             18         17.0            3      3
# 2016-03-31 23:30:00       29             13         15.0            3      3
# 2016-03-31 23:45:00       29             14         15.0            3      3
#
# [262080 rows x 5 columns]

# %%
# create the region grouper

region_grp = df.groupby("region")

region_grp

# %%
# shifting periods

periods = list(range(1,97))

# %%
# generate the lag features

lag_features = region_grp["total_pickups"].shift(periods)

lag_features
# Out:
#                       total_pickups_1  total_pickups_2  total_pickups_3  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN              NaN              NaN
# 2016-01-01 00:15:00              58.0              NaN              NaN
# 2016-01-01 00:30:00             120.0             58.0              NaN
# 2016-01-01 00:45:00             149.0            120.0             58.0
# 2016-01-01 01:00:00             160.0            149.0            120.0
# ...                               ...              ...              ...
# 2016-03-31 22:45:00              22.0             14.0             15.0
# 2016-03-31 23:00:00              14.0             22.0             14.0
# 2016-03-31 23:15:00              17.0             14.0             22.0
# 2016-03-31 23:30:00              18.0             17.0             14.0
# 2016-03-31 23:45:00              13.0             18.0             17.0
#
#                       total_pickups_4  total_pickups_5  total_pickups_6  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN              NaN              NaN
# 2016-01-01 00:15:00               NaN              NaN              NaN
# 2016-01-01 00:30:00               NaN              NaN              NaN
# 2016-01-01 00:45:00               NaN              NaN              NaN
# 2016-01-01 01:00:00              58.0              NaN              NaN
# ...                               ...              ...              ...
# 2016-03-31 22:45:00              13.0              9.0             18.0
# 2016-03-31 23:00:00              15.0             13.0              9.0
# 2016-03-31 23:15:00              14.0             15.0             13.0
# 2016-03-31 23:30:00              22.0             14.0             15.0
# 2016-03-31 23:45:00              14.0             22.0             14.0
#
#                       total_pickups_7  total_pickups_8  total_pickups_9  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN              NaN              NaN
# 2016-01-01 00:15:00               NaN              NaN              NaN
# 2016-01-01 00:30:00               NaN              NaN              NaN
# 2016-01-01 00:45:00               NaN              NaN              NaN
# 2016-01-01 01:00:00               NaN              NaN              NaN
# ...                               ...              ...              ...
# 2016-03-31 22:45:00              13.0             13.0              7.0
# 2016-03-31 23:00:00              18.0             13.0             13.0
# 2016-03-31 23:15:00               9.0             18.0             13.0
# 2016-03-31 23:30:00              13.0              9.0             18.0
# 2016-03-31 23:45:00              15.0             13.0              9.0
#
#                       total_pickups_10  ...  total_pickups_87  \
# tpep_pickup_datetime                    ...
# 2016-01-01 00:00:00                NaN  ...               NaN
# 2016-01-01 00:15:00                NaN  ...               NaN
# 2016-01-01 00:30:00                NaN  ...               NaN
# 2016-01-01 00:45:00                NaN  ...               NaN
# 2016-01-01 01:00:00                NaN  ...               NaN
# ...                                ...  ...               ...
# 2016-03-31 22:45:00               11.0  ...              15.0
# 2016-03-31 23:00:00                7.0  ...               8.0
# 2016-03-31 23:15:00               13.0  ...              10.0
# 2016-03-31 23:30:00               13.0  ...               4.0
# 2016-03-31 23:45:00               18.0  ...              12.0
#
#                       total_pickups_88  total_pickups_89  total_pickups_90  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00                NaN               NaN               NaN
# 2016-01-01 00:15:00                NaN               NaN               NaN
# 2016-01-01 00:30:00                NaN               NaN               NaN
# 2016-01-01 00:45:00                NaN               NaN               NaN
# 2016-01-01 01:00:00                NaN               NaN               NaN
# ...                                ...               ...               ...
# 2016-03-31 22:45:00                8.0              17.0              13.0
# 2016-03-31 23:00:00               15.0               8.0              17.0
# 2016-03-31 23:15:00                8.0              15.0               8.0
# 2016-03-31 23:30:00               10.0               8.0              15.0
# 2016-03-31 23:45:00                4.0              10.0               8.0
#
#                       total_pickups_91  total_pickups_92  total_pickups_93  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00                NaN               NaN               NaN
# 2016-01-01 00:15:00                NaN               NaN               NaN
# 2016-01-01 00:30:00                NaN               NaN               NaN
# 2016-01-01 00:45:00                NaN               NaN               NaN
# 2016-01-01 01:00:00                NaN               NaN               NaN
# ...                                ...               ...               ...
# 2016-03-31 22:45:00                6.0              15.0              10.0
# 2016-03-31 23:00:00               13.0               6.0              15.0
# 2016-03-31 23:15:00               17.0              13.0               6.0
# 2016-03-31 23:30:00                8.0              17.0              13.0
# 2016-03-31 23:45:00               15.0               8.0              17.0
#
#                       total_pickups_94  total_pickups_95  total_pickups_96
# tpep_pickup_datetime
# 2016-01-01 00:00:00                NaN               NaN               NaN
# 2016-01-01 00:15:00                NaN               NaN               NaN
# 2016-01-01 00:30:00                NaN               NaN               NaN
# 2016-01-01 00:45:00                NaN               NaN               NaN
# 2016-01-01 01:00:00                NaN               NaN               NaN
# ...                                ...               ...               ...
# 2016-03-31 22:45:00               12.0              16.0              11.0
# 2016-03-31 23:00:00               10.0              12.0              16.0
# 2016-03-31 23:15:00               15.0              10.0              12.0
# 2016-03-31 23:30:00                6.0              15.0              10.0
# 2016-03-31 23:45:00               13.0               6.0              15.0
#
# [262080 rows x 96 columns]

# %%
# merge them with the original df

data = pd.concat([lag_features,df],axis=1)

data
# Out:
#                       total_pickups_1  total_pickups_2  total_pickups_3  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN              NaN              NaN
# 2016-01-01 00:15:00              58.0              NaN              NaN
# 2016-01-01 00:30:00             120.0             58.0              NaN
# 2016-01-01 00:45:00             149.0            120.0             58.0
# 2016-01-01 01:00:00             160.0            149.0            120.0
# ...                               ...              ...              ...
# 2016-03-31 22:45:00              22.0             14.0             15.0
# 2016-03-31 23:00:00              14.0             22.0             14.0
# 2016-03-31 23:15:00              17.0             14.0             22.0
# 2016-03-31 23:30:00              18.0             17.0             14.0
# 2016-03-31 23:45:00              13.0             18.0             17.0
#
#                       total_pickups_4  total_pickups_5  total_pickups_6  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN              NaN              NaN
# 2016-01-01 00:15:00               NaN              NaN              NaN
# 2016-01-01 00:30:00               NaN              NaN              NaN
# 2016-01-01 00:45:00               NaN              NaN              NaN
# 2016-01-01 01:00:00              58.0              NaN              NaN
# ...                               ...              ...              ...
# 2016-03-31 22:45:00              13.0              9.0             18.0
# 2016-03-31 23:00:00              15.0             13.0              9.0
# 2016-03-31 23:15:00              14.0             15.0             13.0
# 2016-03-31 23:30:00              22.0             14.0             15.0
# 2016-03-31 23:45:00              14.0             22.0             14.0
#
#                       total_pickups_7  total_pickups_8  total_pickups_9  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN              NaN              NaN
# 2016-01-01 00:15:00               NaN              NaN              NaN
# 2016-01-01 00:30:00               NaN              NaN              NaN
# 2016-01-01 00:45:00               NaN              NaN              NaN
# 2016-01-01 01:00:00               NaN              NaN              NaN
# ...                               ...              ...              ...
# 2016-03-31 22:45:00              13.0             13.0              7.0
# 2016-03-31 23:00:00              18.0             13.0             13.0
# 2016-03-31 23:15:00               9.0             18.0             13.0
# 2016-03-31 23:30:00              13.0              9.0             18.0
# 2016-03-31 23:45:00              15.0             13.0              9.0
#
#                       total_pickups_10  ...  total_pickups_92  \
# tpep_pickup_datetime                    ...
# 2016-01-01 00:00:00                NaN  ...               NaN
# 2016-01-01 00:15:00                NaN  ...               NaN
# 2016-01-01 00:30:00                NaN  ...               NaN
# 2016-01-01 00:45:00                NaN  ...               NaN
# 2016-01-01 01:00:00                NaN  ...               NaN
# ...                                ...  ...               ...
# 2016-03-31 22:45:00               11.0  ...              15.0
# 2016-03-31 23:00:00                7.0  ...               6.0
# 2016-03-31 23:15:00               13.0  ...              13.0
# 2016-03-31 23:30:00               13.0  ...              17.0
# 2016-03-31 23:45:00               18.0  ...               8.0
#
#                       total_pickups_93  total_pickups_94  total_pickups_95  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00                NaN               NaN               NaN
# 2016-01-01 00:15:00                NaN               NaN               NaN
# 2016-01-01 00:30:00                NaN               NaN               NaN
# 2016-01-01 00:45:00                NaN               NaN               NaN
# 2016-01-01 01:00:00                NaN               NaN               NaN
# ...                                ...               ...               ...
# 2016-03-31 22:45:00               10.0              12.0              16.0
# 2016-03-31 23:00:00               15.0              10.0              12.0
# 2016-03-31 23:15:00                6.0              15.0              10.0
# 2016-03-31 23:30:00               13.0               6.0              15.0
# 2016-03-31 23:45:00               17.0              13.0               6.0
#
#                       total_pickups_96  region  total_pickups  avg_pickups  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00                NaN       0             58         58.0
# 2016-01-01 00:15:00                NaN       0            120         97.0
# 2016-01-01 00:30:00                NaN       0            149        123.0
# 2016-01-01 00:45:00                NaN       0            160        140.0
# 2016-01-01 01:00:00                NaN       0            187        161.0
# ...                                ...     ...            ...          ...
# 2016-03-31 22:45:00               11.0      29             14         16.0
# 2016-03-31 23:00:00               16.0      29             17         16.0
# 2016-03-31 23:15:00               12.0      29             18         17.0
# 2016-03-31 23:30:00               10.0      29             13         15.0
# 2016-03-31 23:45:00               15.0      29             14         15.0
#
#                       day_of_week  month
# tpep_pickup_datetime
# 2016-01-01 00:00:00             4      1
# 2016-01-01 00:15:00             4      1
# 2016-01-01 00:30:00             4      1
# 2016-01-01 00:45:00             4      1
# 2016-01-01 01:00:00             4      1
# ...                           ...    ...
# 2016-03-31 22:45:00             3      3
# 2016-03-31 23:00:00             3      3
# 2016-03-31 23:15:00             3      3
# 2016-03-31 23:30:00             3      3
# 2016-03-31 23:45:00             3      3
#
# [262080 rows x 101 columns]

# %%
print("The shape of the df before merger ", df.shape)
print("The shape of the df after merger ", data.shape)
# Out:
# The shape of the df before merger  (262080, 5)
# The shape of the df after merger  (262080, 101)

# %%
# rows having missing values

data.isna().any(axis=1).sum()
# Out:
# np.int64(2880)

# %%
# drop the missing values

data.dropna(inplace=True)

# %%
data.isna().any(axis=1).sum()
# Out:
# np.int64(0)

# %%
mapper = {name:f"lag_{ind+1}" for ind, name in enumerate(data.columns[0:96])}

mapper
# Out:
# {'total_pickups_1': 'lag_1',
#  'total_pickups_2': 'lag_2',
#  'total_pickups_3': 'lag_3',
#  'total_pickups_4': 'lag_4',
#  'total_pickups_5': 'lag_5',
#  'total_pickups_6': 'lag_6',
#  'total_pickups_7': 'lag_7',
#  'total_pickups_8': 'lag_8',
#  'total_pickups_9': 'lag_9',
#  'total_pickups_10': 'lag_10',
#  'total_pickups_11': 'lag_11',
#  'total_pickups_12': 'lag_12',
#  'total_pickups_13': 'lag_13',
#  'total_pickups_14': 'lag_14',
#  'total_pickups_15': 'lag_15',
#  'total_pickups_16': 'lag_16',
#  'total_pickups_17': 'lag_17',
#  'total_pickups_18': 'lag_18',
#  'total_pickups_19': 'lag_19',
#  'total_pickups_20': 'lag_20',
#  'total_pickups_21': 'lag_21',
#  'total_pickups_22': 'lag_22',
#  'total_pickups_23': 'lag_23',
#  'total_pickups_24': 'lag_24',
#  'total_pickups_25': 'lag_25',
#  'total_pickups_26': 'lag_26',
#  'total_pickups_27': 'lag_27',
#  'total_pickups_28': 'lag_28',
#  'total_pickups_29': 'lag_29',
#  'total_pickups_30': 'lag_30',
#  'total_pickups_31': 'lag_31',
#  'total_pickups_32': 'lag_32',
#  'total_pickups_33': 'lag_33',
#  'total_pickups_34': 'lag_34',
#  'total_pickups_35': 'lag_35',
#  'total_pickups_36': 'lag_36',
#  'total_pickups_37': 'lag_37',
#  'total_pickups_38': 'lag_38',
#  'total_pickups_39': 'lag_39',
#  'total_pickups_40': 'lag_40',
#  'total_pickups_41': 'lag_41',
#  'total_pickups_42': 'lag_42',
#  'total_pickups_43': 'lag_43',
#  'total_pickups_44': 'lag_44',
#  'total_pickups_45': 'lag_45',
#  'total_pickups_46': 'lag_46',
#  'total_pickups_47': 'lag_47',
#  'total_pickups_48': 'lag_48',
#  'total_pickups_49': 'lag_49',
#  'total_pickups_50': 'lag_50',
#  'total_pickups_51': 'lag_51',
#  'total_pickups_52': 'lag_52',
#  'total_pickups_53': 'lag_53',
#  'total_pickups_54': 'lag_54',
#  'total_pickups_55': 'lag_55',
#  'total_pickups_56': 'lag_56',
#  'total_pickups_57': 'lag_57',
#  'total_pickups_58': 'lag_58',
#  'total_pickups_59': 'lag_59',
#  'total_pickups_60': 'lag_60',
#  'total_pickups_61': 'lag_61',
#  'total_pickups_62': 'lag_62',
#  'total_pickups_63': 'lag_63',
#  'total_pickups_64': 'lag_64',
#  'total_pickups_65': 'lag_65',
#  'total_pickups_66': 'lag_66',
#  'total_pickups_67': 'lag_67',
#  'total_pickups_68': 'lag_68',
#  'total_pickups_69': 'lag_69',
#  'total_pickups_70': 'lag_70',
#  'total_pickups_71': 'lag_71',
#  'total_pickups_72': 'lag_72',
#  'total_pickups_73': 'lag_73',
#  'total_pickups_74': 'lag_74',
#  'total_pickups_75': 'lag_75',
#  'total_pickups_76': 'lag_76',
#  'total_pickups_77': 'lag_77',
#  'total_pickups_78': 'lag_78',
#  'total_pickups_79': 'lag_79',
#  'total_pickups_80': 'lag_80',
#  'total_pickups_81': 'lag_81',
#  'total_pickups_82': 'lag_82',
#  'total_pickups_83': 'lag_83',
#  'total_pickups_84': 'lag_84',
#  'total_pickups_85': 'lag_85',
#  'total_pickups_86': 'lag_86',
#  'total_pickups_87': 'lag_87',
#  'total_pickups_88': 'lag_88',
#  'total_pickups_89': 'lag_89',
#  'total_pickups_90': 'lag_90',
#  'total_pickups_91': 'lag_91',
#  'total_pickups_92': 'lag_92',
#  'total_pickups_93': 'lag_93',
#  'total_pickups_94': 'lag_94',
#  'total_pickups_95': 'lag_95',
#  'total_pickups_96': 'lag_96'}

# %%
# replace the column names

data = data.rename(columns=mapper)

# %%
data.head()
# Out:
#                       lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  \
# tpep_pickup_datetime
# 2016-01-02 00:00:00    49.0   30.0   35.0   42.0   47.0   37.0   25.0   31.0
# 2016-01-02 00:15:00    53.0   49.0   30.0   35.0   42.0   47.0   37.0   25.0
# 2016-01-02 00:30:00    34.0   53.0   49.0   30.0   35.0   42.0   47.0   37.0
# 2016-01-02 00:45:00    35.0   34.0   53.0   49.0   30.0   35.0   42.0   47.0
# 2016-01-02 01:00:00    33.0   35.0   34.0   53.0   49.0   30.0   35.0   42.0
#
#                       lag_9  lag_10  ...  lag_92  lag_93  lag_94  lag_95  \
# tpep_pickup_datetime                 ...
# 2016-01-02 00:00:00    33.0    31.0  ...   187.0   160.0   149.0   120.0
# 2016-01-02 00:15:00    31.0    33.0  ...   194.0   187.0   160.0   149.0
# 2016-01-02 00:30:00    25.0    31.0  ...   180.0   194.0   187.0   160.0
# 2016-01-02 00:45:00    37.0    25.0  ...   197.0   180.0   194.0   187.0
# 2016-01-02 01:00:00    47.0    37.0  ...   185.0   197.0   180.0   194.0
#
#                       lag_96  region  total_pickups  avg_pickups  day_of_week  \
# tpep_pickup_datetime
# 2016-01-02 00:00:00     58.0       0             53         45.0            5
# 2016-01-02 00:15:00    120.0       0             34         41.0            5
# 2016-01-02 00:30:00    149.0       0             35         39.0            5
# 2016-01-02 00:45:00    160.0       0             33         36.0            5
# 2016-01-02 01:00:00    187.0       0             34         35.0            5
#
#                       month
# tpep_pickup_datetime
# 2016-01-02 00:00:00       1
# 2016-01-02 00:15:00       1
# 2016-01-02 00:30:00       1
# 2016-01-02 00:45:00       1
# 2016-01-02 01:00:00       1
#
# [5 rows x 101 columns]

# %%
# shape of the data

data.shape
# Out:
# (259200, 101)

# %%
# number of rows in each month

data['month'].value_counts()
# Out:
# month
# 3    89280
# 1    86400
# 2    83520
# Name: count, dtype: int64

# %%
data
# Out:
#                       lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  \
# tpep_pickup_datetime
# 2016-01-02 00:00:00    49.0   30.0   35.0   42.0   47.0   37.0   25.0   31.0
# 2016-01-02 00:15:00    53.0   49.0   30.0   35.0   42.0   47.0   37.0   25.0
# 2016-01-02 00:30:00    34.0   53.0   49.0   30.0   35.0   42.0   47.0   37.0
# 2016-01-02 00:45:00    35.0   34.0   53.0   49.0   30.0   35.0   42.0   47.0
# 2016-01-02 01:00:00    33.0   35.0   34.0   53.0   49.0   30.0   35.0   42.0
# ...                     ...    ...    ...    ...    ...    ...    ...    ...
# 2016-03-31 22:45:00    22.0   14.0   15.0   13.0    9.0   18.0   13.0   13.0
# 2016-03-31 23:00:00    14.0   22.0   14.0   15.0   13.0    9.0   18.0   13.0
# 2016-03-31 23:15:00    17.0   14.0   22.0   14.0   15.0   13.0    9.0   18.0
# 2016-03-31 23:30:00    18.0   17.0   14.0   22.0   14.0   15.0   13.0    9.0
# 2016-03-31 23:45:00    13.0   18.0   17.0   14.0   22.0   14.0   15.0   13.0
#
#                       lag_9  lag_10  ...  lag_92  lag_93  lag_94  lag_95  \
# tpep_pickup_datetime                 ...
# 2016-01-02 00:00:00    33.0    31.0  ...   187.0   160.0   149.0   120.0
# 2016-01-02 00:15:00    31.0    33.0  ...   194.0   187.0   160.0   149.0
# 2016-01-02 00:30:00    25.0    31.0  ...   180.0   194.0   187.0   160.0
# 2016-01-02 00:45:00    37.0    25.0  ...   197.0   180.0   194.0   187.0
# 2016-01-02 01:00:00    47.0    37.0  ...   185.0   197.0   180.0   194.0
# ...                     ...     ...  ...     ...     ...     ...     ...
# 2016-03-31 22:45:00     7.0    11.0  ...    15.0    10.0    12.0    16.0
# 2016-03-31 23:00:00    13.0     7.0  ...     6.0    15.0    10.0    12.0
# 2016-03-31 23:15:00    13.0    13.0  ...    13.0     6.0    15.0    10.0
# 2016-03-31 23:30:00    18.0    13.0  ...    17.0    13.0     6.0    15.0
# 2016-03-31 23:45:00     9.0    18.0  ...     8.0    17.0    13.0     6.0
#
#                       lag_96  region  total_pickups  avg_pickups  day_of_week  \
# tpep_pickup_datetime
# 2016-01-02 00:00:00     58.0       0             53         45.0            5
# 2016-01-02 00:15:00    120.0       0             34         41.0            5
# 2016-01-02 00:30:00    149.0       0             35         39.0            5
# 2016-01-02 00:45:00    160.0       0             33         36.0            5
# 2016-01-02 01:00:00    187.0       0             34         35.0            5
# ...                      ...     ...            ...          ...          ...
# 2016-03-31 22:45:00     11.0      29             14         16.0            3
# 2016-03-31 23:00:00     16.0      29             17         16.0            3
# 2016-03-31 23:15:00     12.0      29             18         17.0            3
# 2016-03-31 23:30:00     10.0      29             13         15.0            3
# 2016-03-31 23:45:00     15.0      29             14         15.0            3
#
#                       month
# tpep_pickup_datetime
# 2016-01-02 00:00:00       1
# 2016-01-02 00:15:00       1
# 2016-01-02 00:30:00       1
# 2016-01-02 00:45:00       1
# 2016-01-02 01:00:00       1
# ...                     ...
# 2016-03-31 22:45:00       3
# 2016-03-31 23:00:00       3
# 2016-03-31 23:15:00       3
# 2016-03-31 23:30:00       3
# 2016-03-31 23:45:00       3
#
# [259200 rows x 101 columns]

# %%
data.loc[data["month"].isin([1,2]),"lag_1":"day_of_week"]
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  total_pickups  \
# tpep_pickup_datetime
# 2016-01-01 01:00:00   160.0  149.0  120.0   58.0       0            187
# 2016-01-01 01:15:00   187.0  160.0  149.0  120.0       0            194
# 2016-01-01 01:30:00   194.0  187.0  160.0  149.0       0            180
# 2016-01-01 01:45:00   180.0  194.0  187.0  160.0       0            197
# 2016-01-01 02:00:00   197.0  180.0  194.0  187.0       0            185
# ...                     ...    ...    ...    ...     ...            ...
# 2016-02-29 22:45:00    15.0    9.0   11.0   11.0      29             12
# 2016-02-29 23:00:00    12.0   15.0    9.0   11.0      29             17
# 2016-02-29 23:15:00    17.0   12.0   15.0    9.0      29             15
# 2016-02-29 23:30:00    15.0   17.0   12.0   15.0      29             15
# 2016-02-29 23:45:00    15.0   15.0   17.0   12.0      29             12
#
#                       avg_pickups  day_of_week
# tpep_pickup_datetime
# 2016-01-01 01:00:00         161.0            4
# 2016-01-01 01:15:00         175.0            4
# 2016-01-01 01:30:00         177.0            4
# 2016-01-01 01:45:00         185.0            4
# 2016-01-01 02:00:00         185.0            4
# ...                           ...          ...
# 2016-02-29 22:45:00          12.0            0
# 2016-02-29 23:00:00          14.0            0
# 2016-02-29 23:15:00          14.0            0
# 2016-02-29 23:30:00          15.0            0
# 2016-02-29 23:45:00          14.0            0
#
# [172680 rows x 8 columns]

# %%
# split the data

trainset = data.loc[data["month"].isin([1,2]),"lag_1":"day_of_week"]

testset = data.loc[data["month"].isin([3]),"lag_1":"day_of_week"]

# %%
trainset
# Out:
#                       lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  \
# tpep_pickup_datetime
# 2016-01-02 00:00:00    49.0   30.0   35.0   42.0   47.0   37.0   25.0   31.0
# 2016-01-02 00:15:00    53.0   49.0   30.0   35.0   42.0   47.0   37.0   25.0
# 2016-01-02 00:30:00    34.0   53.0   49.0   30.0   35.0   42.0   47.0   37.0
# 2016-01-02 00:45:00    35.0   34.0   53.0   49.0   30.0   35.0   42.0   47.0
# 2016-01-02 01:00:00    33.0   35.0   34.0   53.0   49.0   30.0   35.0   42.0
# ...                     ...    ...    ...    ...    ...    ...    ...    ...
# 2016-02-29 22:45:00    15.0    9.0   11.0   11.0   16.0    4.0    8.0   10.0
# 2016-02-29 23:00:00    12.0   15.0    9.0   11.0   11.0   16.0    4.0    8.0
# 2016-02-29 23:15:00    17.0   12.0   15.0    9.0   11.0   11.0   16.0    4.0
# 2016-02-29 23:30:00    15.0   17.0   12.0   15.0    9.0   11.0   11.0   16.0
# 2016-02-29 23:45:00    15.0   15.0   17.0   12.0   15.0    9.0   11.0   11.0
#
#                       lag_9  lag_10  ...  lag_91  lag_92  lag_93  lag_94  \
# tpep_pickup_datetime                 ...
# 2016-01-02 00:00:00    33.0    31.0  ...   194.0   187.0   160.0   149.0
# 2016-01-02 00:15:00    31.0    33.0  ...   180.0   194.0   187.0   160.0
# 2016-01-02 00:30:00    25.0    31.0  ...   197.0   180.0   194.0   187.0
# 2016-01-02 00:45:00    37.0    25.0  ...   185.0   197.0   180.0   194.0
# 2016-01-02 01:00:00    47.0    37.0  ...   156.0   185.0   197.0   180.0
# ...                     ...     ...  ...     ...     ...     ...     ...
# 2016-02-29 22:45:00    13.0    10.0  ...    25.0    18.0    11.0    12.0
# 2016-02-29 23:00:00    10.0    13.0  ...    43.0    25.0    18.0    11.0
# 2016-02-29 23:15:00     8.0    10.0  ...    27.0    43.0    25.0    18.0
# 2016-02-29 23:30:00     4.0     8.0  ...    12.0    27.0    43.0    25.0
# 2016-02-29 23:45:00    16.0     4.0  ...     9.0    12.0    27.0    43.0
#
#                       lag_95  lag_96  region  total_pickups  avg_pickups  \
# tpep_pickup_datetime
# 2016-01-02 00:00:00    120.0    58.0       0             53         45.0
# 2016-01-02 00:15:00    149.0   120.0       0             34         41.0
# 2016-01-02 00:30:00    160.0   149.0       0             35         39.0
# 2016-01-02 00:45:00    187.0   160.0       0             33         36.0
# 2016-01-02 01:00:00    194.0   187.0       0             34         35.0
# ...                      ...     ...     ...            ...          ...
# 2016-02-29 22:45:00     13.0    11.0      29             12         12.0
# 2016-02-29 23:00:00     12.0    13.0      29             17         14.0
# 2016-02-29 23:15:00     11.0    12.0      29             15         14.0
# 2016-02-29 23:30:00     18.0    11.0      29             15         15.0
# 2016-02-29 23:45:00     25.0    18.0      29             12         14.0
#
#                       day_of_week
# tpep_pickup_datetime
# 2016-01-02 00:00:00             5
# 2016-01-02 00:15:00             5
# 2016-01-02 00:30:00             5
# 2016-01-02 00:45:00             5
# 2016-01-02 01:00:00             5
# ...                           ...
# 2016-02-29 22:45:00             0
# 2016-02-29 23:00:00             0
# 2016-02-29 23:15:00             0
# 2016-02-29 23:30:00             0
# 2016-02-29 23:45:00             0
#
# [169920 rows x 100 columns]

# %%
# save the train and test data

train_data_save_path = "../data/processed/train.csv"

test_data_save_path = "../data/processed/test.csv"

trainset.to_csv(train_data_save_path, index=True)
testset.to_csv(test_data_save_path, index=True)

# %%
# make X_train and y_train

X_train = trainset.drop(columns=["total_pickups"])

y_train = trainset["total_pickups"]

# %%
X_train.shape
# Out:
# (169920, 99)

# %%
X_train
# Out:
#                       lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  \
# tpep_pickup_datetime
# 2016-01-02 00:00:00    49.0   30.0   35.0   42.0   47.0   37.0   25.0   31.0
# 2016-01-02 00:15:00    53.0   49.0   30.0   35.0   42.0   47.0   37.0   25.0
# 2016-01-02 00:30:00    34.0   53.0   49.0   30.0   35.0   42.0   47.0   37.0
# 2016-01-02 00:45:00    35.0   34.0   53.0   49.0   30.0   35.0   42.0   47.0
# 2016-01-02 01:00:00    33.0   35.0   34.0   53.0   49.0   30.0   35.0   42.0
# ...                     ...    ...    ...    ...    ...    ...    ...    ...
# 2016-02-29 22:45:00    15.0    9.0   11.0   11.0   16.0    4.0    8.0   10.0
# 2016-02-29 23:00:00    12.0   15.0    9.0   11.0   11.0   16.0    4.0    8.0
# 2016-02-29 23:15:00    17.0   12.0   15.0    9.0   11.0   11.0   16.0    4.0
# 2016-02-29 23:30:00    15.0   17.0   12.0   15.0    9.0   11.0   11.0   16.0
# 2016-02-29 23:45:00    15.0   15.0   17.0   12.0   15.0    9.0   11.0   11.0
#
#                       lag_9  lag_10  ...  lag_90  lag_91  lag_92  lag_93  \
# tpep_pickup_datetime                 ...
# 2016-01-02 00:00:00    33.0    31.0  ...   180.0   194.0   187.0   160.0
# 2016-01-02 00:15:00    31.0    33.0  ...   197.0   180.0   194.0   187.0
# 2016-01-02 00:30:00    25.0    31.0  ...   185.0   197.0   180.0   194.0
# 2016-01-02 00:45:00    37.0    25.0  ...   156.0   185.0   197.0   180.0
# 2016-01-02 01:00:00    47.0    37.0  ...   150.0   156.0   185.0   197.0
# ...                     ...     ...  ...     ...     ...     ...     ...
# 2016-02-29 22:45:00    13.0    10.0  ...    43.0    25.0    18.0    11.0
# 2016-02-29 23:00:00    10.0    13.0  ...    27.0    43.0    25.0    18.0
# 2016-02-29 23:15:00     8.0    10.0  ...    12.0    27.0    43.0    25.0
# 2016-02-29 23:30:00     4.0     8.0  ...     9.0    12.0    27.0    43.0
# 2016-02-29 23:45:00    16.0     4.0  ...    14.0     9.0    12.0    27.0
#
#                       lag_94  lag_95  lag_96  region  avg_pickups  day_of_week
# tpep_pickup_datetime
# 2016-01-02 00:00:00    149.0   120.0    58.0       0         45.0            5
# 2016-01-02 00:15:00    160.0   149.0   120.0       0         41.0            5
# 2016-01-02 00:30:00    187.0   160.0   149.0       0         39.0            5
# 2016-01-02 00:45:00    194.0   187.0   160.0       0         36.0            5
# 2016-01-02 01:00:00    180.0   194.0   187.0       0         35.0            5
# ...                      ...     ...     ...     ...          ...          ...
# 2016-02-29 22:45:00     12.0    13.0    11.0      29         12.0            0
# 2016-02-29 23:00:00     11.0    12.0    13.0      29         14.0            0
# 2016-02-29 23:15:00     18.0    11.0    12.0      29         14.0            0
# 2016-02-29 23:30:00     25.0    18.0    11.0      29         15.0            0
# 2016-02-29 23:45:00     43.0    25.0    18.0      29         14.0            0
#
# [169920 rows x 99 columns]

# %%
y_train
# Out:
# tpep_pickup_datetime
# 2016-01-02 00:00:00    53
# 2016-01-02 00:15:00    34
# 2016-01-02 00:30:00    35
# 2016-01-02 00:45:00    33
# 2016-01-02 01:00:00    34
#                        ..
# 2016-02-29 22:45:00    12
# 2016-02-29 23:00:00    17
# 2016-02-29 23:15:00    15
# 2016-02-29 23:30:00    15
# 2016-02-29 23:45:00    12
# Name: total_pickups, Length: 169920, dtype: int64

# %%
# make X_test and y_test

X_test = testset.drop(columns=["total_pickups"])

y_test = testset["total_pickups"]

# %%
X_test.shape
# Out:
# (89280, 99)

# %%
X_test
# Out:
#                       lag_1  lag_2  lag_3  lag_4  lag_5  lag_6  lag_7  lag_8  \
# tpep_pickup_datetime
# 2016-03-01 00:00:00    36.0   44.0   31.0   29.0   41.0   49.0   35.0   47.0
# 2016-03-01 00:15:00    41.0   36.0   44.0   31.0   29.0   41.0   49.0   35.0
# 2016-03-01 00:30:00    35.0   41.0   36.0   44.0   31.0   29.0   41.0   49.0
# 2016-03-01 00:45:00    47.0   35.0   41.0   36.0   44.0   31.0   29.0   41.0
# 2016-03-01 01:00:00    34.0   47.0   35.0   41.0   36.0   44.0   31.0   29.0
# ...                     ...    ...    ...    ...    ...    ...    ...    ...
# 2016-03-31 22:45:00    22.0   14.0   15.0   13.0    9.0   18.0   13.0   13.0
# 2016-03-31 23:00:00    14.0   22.0   14.0   15.0   13.0    9.0   18.0   13.0
# 2016-03-31 23:15:00    17.0   14.0   22.0   14.0   15.0   13.0    9.0   18.0
# 2016-03-31 23:30:00    18.0   17.0   14.0   22.0   14.0   15.0   13.0    9.0
# 2016-03-31 23:45:00    13.0   18.0   17.0   14.0   22.0   14.0   15.0   13.0
#
#                       lag_9  lag_10  ...  lag_90  lag_91  lag_92  lag_93  \
# tpep_pickup_datetime                 ...
# 2016-03-01 00:00:00    37.0    37.0  ...    19.0    26.0    23.0    41.0
# 2016-03-01 00:15:00    47.0    37.0  ...    17.0    19.0    26.0    23.0
# 2016-03-01 00:30:00    35.0    47.0  ...    15.0    17.0    19.0    26.0
# 2016-03-01 00:45:00    49.0    35.0  ...    13.0    15.0    17.0    19.0
# 2016-03-01 01:00:00    41.0    49.0  ...    17.0    13.0    15.0    17.0
# ...                     ...     ...  ...     ...     ...     ...     ...
# 2016-03-31 22:45:00     7.0    11.0  ...    13.0     6.0    15.0    10.0
# 2016-03-31 23:00:00    13.0     7.0  ...    17.0    13.0     6.0    15.0
# 2016-03-31 23:15:00    13.0    13.0  ...     8.0    17.0    13.0     6.0
# 2016-03-31 23:30:00    18.0    13.0  ...    15.0     8.0    17.0    13.0
# 2016-03-31 23:45:00     9.0    18.0  ...     8.0    15.0     8.0    17.0
#
#                       lag_94  lag_95  lag_96  region  avg_pickups  day_of_week
# tpep_pickup_datetime
# 2016-03-01 00:00:00     48.0    87.0    61.0       0         39.0            1
# 2016-03-01 00:15:00     41.0    48.0    87.0       0         37.0            1
# 2016-03-01 00:30:00     23.0    41.0    48.0       0         41.0            1
# 2016-03-01 00:45:00     26.0    23.0    41.0       0         38.0            1
# 2016-03-01 01:00:00     19.0    26.0    23.0       0         35.0            1
# ...                      ...     ...     ...     ...          ...          ...
# 2016-03-31 22:45:00     12.0    16.0    11.0      29         16.0            3
# 2016-03-31 23:00:00     10.0    12.0    16.0      29         16.0            3
# 2016-03-31 23:15:00     15.0    10.0    12.0      29         17.0            3
# 2016-03-31 23:30:00      6.0    15.0    10.0      29         15.0            3
# 2016-03-31 23:45:00     13.0     6.0    15.0      29         15.0            3
#
# [89280 rows x 99 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error

# %%
from sklearn import set_config

set_config(transform_output="pandas")

# %%
# encode the data

encoder = ColumnTransformer([
    ("ohe", OneHotEncoder(drop="first",sparse_output=False), ["region","day_of_week"])
], remainder="passthrough", n_jobs=-1,force_int_remainder_cols=False)

# %%
encoder
# Out:
# ColumnTransformer(force_int_remainder_cols=False, n_jobs=-1,
#                   remainder='passthrough',
#                   transformers=[('ohe',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['region', 'day_of_week'])])

# %%
# encode the train and test data

X_train_encoded = encoder.fit_transform(X_train)
X_test_encoded = encoder.transform(X_test)

# %%
# train the model

lr = LinearRegression()

# fit on the training data
lr.fit(X_train_encoded, y_train)
# Out:
# LinearRegression()

# %%
# make predictions on the train data

y_pred_train = lr.predict(X_train_encoded)

# %%
# make predictions on the test data

y_pred_test = lr.predict(X_test_encoded)

# %%
# evaluate the baseline model

train_mape = mean_absolute_percentage_error(y_train, y_pred_train)

test_mape = mean_absolute_percentage_error(y_test, y_pred_test)

# %%
test_mape
# Out:
# 0.03643495855244869

# %%
print(f"MAPE on trainset is {(train_mape * 100):.2f}%")
print(f"MAPE on testset is {(test_mape * 100):.2f}%")
# Out:
# MAPE on trainset is 4.06%
# MAPE on testset is 3.64%
